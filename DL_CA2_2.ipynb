# %% [markdown]
# <a href="https://colab.research.google.com/github/Amirhossein-ilkhani/CNN_Models/blob/master/DL_CA2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # New Section

# %%
! python3 "/content/drive/MyDrive/DL_CA2_2/train.py"
# Out:
# cuda
# Tesla T4
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#             Conv2d-4          [-1, 128, 32, 32]          73,856
#        BatchNorm2d-5          [-1, 128, 32, 32]             256
#               ReLU-6          [-1, 128, 32, 32]               0
#          MaxPool2d-7          [-1, 128, 16, 16]               0
#             Conv2d-8            [-1, 8, 16, 16]           1,032
#        BatchNorm2d-9            [-1, 8, 16, 16]              16
#              ReLU-10            [-1, 8, 16, 16]               0
#            Conv2d-11           [-1, 16, 16, 16]           1,168
#       BatchNorm2d-12           [-1, 16, 16, 16]              32
# ...
